# %% [markdown]
# # Lead-priority scoring (proxy labels)
#
# Trains logistic regression and random forest on **synthetic** Maps-like lead features.
# Labels are a documented sales **proxy**, not CRM conversions — see `ml/proxy_labels.py`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from ml.train_lead_scorer import train
results = train(n=2500, seed=42, db_path=ROOT / "data" / "aade.db")
results["models"]["logistic_regression"]["accuracy"], results["models"]["random_forest"]["f1"]
